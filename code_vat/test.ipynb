# %%
import numpy as np 
from matplotlib import pyplot as plt

# %%
e_point5 = [0.12,0.51,0.63,0.635,0.651,0.648]
e1 = [0.17,0.51,0.633,0.64,0.65,0.65]
e5 = [0.13,0.28,0.569,0.582,0.651,0.642]

n = np.arange(6)
plt.plot(n,e_point5, label='\epsilon=0.5')
plt.plot(n,e1, label='\epsilon=1')
plt.plot(n,e5, label='\epsilon=5')
plt.xlabel('number of epoch')
plt.ylabel('Accuracy')
plt.legend()

# %%
VAT_loss5 = [2.277,2.06,1.471,1.40,1.19,1.20,1.29,1.18,1.19,1.19,1.14,1.16,1.15,1.17,1.21,1.14,1.17, 1.17,1.19,1.20]
base_loss = [2.3190322380065918, 1.6567928552627564, 1.3475937719345092, 1.2263789434432983, 1.2355452108383178, 1.2118582820892334, 1.2284839916229249, 1.168825159072876, 1.2275461254119873, 1.2902051048278809, 1.209295726776123, 1.30916676902771, 1.2707264633178712, 1.2763612270355225, 1.2014729013442993, 1.2891142292022706, 1.313509391784668, 1.2666805648803712, 1.401583724975586, 1.3489147071838379]

n1 = np.arange(len(base_loss))
print(len(VAT_loss5))
print(len(base_loss))

plt.plot(n1, VAT_loss5, label='BERT-mix-vat')
plt.plot(n1, base_loss, label='BERT')
plt.xlabel('epoch')
plt.ylabel('validation loss')
plt.legend()
# Out:
# 20
# 20
